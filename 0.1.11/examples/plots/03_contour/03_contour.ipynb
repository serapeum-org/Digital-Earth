# %% [markdown]
# # 3 · `contour`
#
# `Map.contour` renders a raster as **line contours (isolines)** (cleopatra `ArrayGlyph`, `kind="contour"`). `Map` reprojects via pyramids and draws on a shared axes; `colorbar()` adds one aggregated bar.

# %% [markdown]
# **Setup** — inline plots and the path to the bundled Lisbon DEM.

# %%
# %matplotlib inline
from pathlib import Path

# Locate the bundled Lisbon DEM from the repo root (works from docs/ or the repo root).
ROOT = Path.cwd()
while not (ROOT / "examples" / "data" / "LisbonElevation.tif").exists() and ROOT != ROOT.parent:
    ROOT = ROOT.parent
DEM = str(ROOT / "examples" / "data" / "LisbonElevation.tif")
from pyramids.dataset import Dataset
from digitalearth.scene import Map
ds = Dataset.read_file(DEM)
# Out:
# 2026-05-28 20:29:36 | INFO | pyramids.base.config | Logging is configured.

# %% [markdown]
# Draw the Lisbon DEM with `Map.contour`. No fill, so no colorbar.

# %%
m = Map(crs=ds.epsg, figsize=(9, 7))
m.contour(ds, cmap='terrain')
m.set_title('contour')
m.fig;

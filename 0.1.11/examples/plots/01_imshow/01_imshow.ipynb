# %% [markdown]
# # 1 · `imshow`
#
# `Map.imshow` renders a raster as **a pixel grid** (cleopatra `ArrayGlyph`, `kind="imshow"`). `Map` reprojects via pyramids and draws on a shared axes; `colorbar()` adds one aggregated bar.

# %% [markdown]
# **Setup** — inline plots and the path to the bundled Lisbon DEM.

# %%
# %matplotlib inline
from pathlib import Path

# Locate the bundled Lisbon DEM from the repo root (works from docs/ or the repo root).
ROOT = Path.cwd()
while not (ROOT / "examples" / "data" / "LisbonElevation.tif").exists() and ROOT != ROOT.parent:
    ROOT = ROOT.parent
DEM = str(ROOT / "examples" / "data" / "LisbonElevation.tif")
from pyramids.dataset import Dataset
from digitalearth.scene import Map
ds = Dataset.read_file(DEM)
# Out:
# 2026-05-28 20:29:26 | INFO | pyramids.base.config | Logging is configured.

# %% [markdown]
# Draw the Lisbon DEM with `Map.imshow`. Honours the data extent; fastest for dense rasters.

# %%
m = Map(crs=ds.epsg, figsize=(9, 7))
m.imshow(ds, cmap='terrain')
m.colorbar(label='elevation (m)')
m.set_title('imshow')
m.fig;
